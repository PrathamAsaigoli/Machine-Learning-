# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import tensorflow as tf
# import torch
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import warnings

# %%
df = pd.read_csv("HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# ...

# %%
df.tail(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14989                0.43             0.57               2
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                0.76             0.83               6
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14989                   159                   3              1     1
# 14990                   228                   5              1     1
# 14991                   257                   4              0     1
# ...

# %%
df.left.value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
people_left  = df[df.left==1]

# %%
people_left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
people_retained = df[df.left==0]

# %%
people_retained
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# ...                   ...              ...             ...
# 14206                0.90             0.55               3
# 14207                0.74             0.95               5
# 14208                0.85             0.54               3
# 14209                0.33             0.65               3
# 14210                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2000                    215                   3              0     0
# 2001                    202                   3              0     0
# ...

# %% [markdown]
# # EDA

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %% [markdown]
# # Feature extraction

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
featuers = df[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years','salary']]
featuers
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
salary_dummy = pd.get_dummies(featuers.salary)
salary_dummy
# Out:
#         high    low  medium
# 0      False   True   False
# 1      False  False    True
# 2      False  False    True
# 3      False   True   False
# 4      False   True   False
# ...      ...    ...     ...
# 14994  False   True   False
# 14995  False   True   False
# 14996  False   True   False
# 14997  False   True   False
# 14998  False   True   False
#
# [14999 rows x 3 columns]

# %%
featuers_updated = pd.concat([featuers,salary_dummy],axis=1)
featuers_updated
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary   high    low  medium
# 0         low  False   True   False
# 1      medium  False  False    True
# ...

# %%
featuers_updated.drop(columns=['salary','medium'], inplace=True)

# %%
X = featuers_updated
y = df[['left']]

# %%
sc = StandardScaler()

# %%
X_std = sc.fit_transform(X)

# %%
X_train,X_test, y_train, y_test = train_test_split(X_std,y,test_size=0.2,random_state=10)

# %%
lr_model = LogisticRegression()
lr_model
# Out:
# LogisticRegression()

# %%
lr_model.fit(X_train,y_train)
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_predic = lr_model.predict(X_test)

# %%
print(y_test)
# Out:
#        left
# 13982     0
# 822       1
# 13751     0
# 9656      0
# 13497     0
# ...     ...
# 3876      0
# 11504     0
# 2435      0
# 5161      0
# 5184      0
#
# [3000 rows x 1 columns]

# %% [markdown]
# # Predicting Different Values

# %%
print(lr_model.predict([[0.40,170,1,False,False]]))
# Out:
# [1]

# %% [markdown]
# # Accuracy

# %%
print((accuracy_score(y_test,y_predic)*100),'%')
# Out:
# 76.96666666666667 %

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test,y_predic)
cm
# Out:
# array([[2116,  150],
#        [ 541,  193]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >
